# %%
# %matplotlib inline

from skimage import (
    util,
    filters,
)

import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (25, 30)

# %%
ECG_img = io.imread("./Data/ECG_001.jpeg")

_ = plt.imshow(
    ECG_img
)

# %%
ECG_img = filters.unsharp_mask(ECG_img)

_ = plt.imshow(
    ECG_img
)

# %%
ECG_data = util.invert(color.rgb2grey(ECG_img))

_ = plt.imshow(
    ECG_data,
    cmap='gray'
)

# %%
ECG_pure = np.zeros(ECG_data.shape)

ECG_pure[
    np.where(ECG_data == np.max(ECG_data, axis=0))
] = 1

_ = plt.imshow(
    ECG_pure,
    cmap='gray'
)

# %%
with open('./Data/ECG_001_NG.pkl', 'wb+') as out_file:
    pickle.dump(ECG_pure, out_file)
